# %% [markdown]
# <a href="https://colab.research.google.com/github/saonongjang/coding_excercise/blob/main/Scipy_excercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#scipy 연습
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

x = np.array([1,2,3,4,5])
y = np.array([1.,0.8,0.4,0.3,0.2])

plt.plot(x,y, '*')

# %%
#Linear interpolation(선형보간)

f_lin = interpolate.interp1d(x,y)
x_new = np.arange(1,5,0.1)
y_new = f_lin(x_new)

fig, ax = plt.subplots()
ax.plot(x,y,'o', label = 'Data')
ax.plot(x_new, y_new, label='Linear')
ax.legend()

# %%
#Splint interpolation(곡선보간)

tck = interpolate.splrep(x,y,s=0)
y_spl = interpolate.splev(x_new,tck,der=0)

fig, ax = plt.subplots()
ax.plot(x,y,'o', label = 'Data')
ax.plot(x_new, y_spl,label = "Spline")
ax.legend()
